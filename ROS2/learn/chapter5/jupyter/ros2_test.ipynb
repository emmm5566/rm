# %%
# 导入rclpy
import rclpy
from rclpy.node import Node

# %%
# 初始化rclpy
rclpy.init()

# %%
# 新建一个节点
node = Node("test_node")
node.get_logger().info("test_node start")
# Out:
# [INFO] [1770539847.499915356] [test_node]: test_node start
# True

# %%
# 保持节点运行，检测是否收到退出指令（Ctrl+C）
rclpy.spin(node)
